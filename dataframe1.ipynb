# %% [markdown]
# <a href="https://colab.research.google.com/github/plsarma85/pysparkDF/blob/main/dataframe1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pyspark
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 20.9 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=601bc18f182a4cb64d100e3ba711edf22958d2d226710793b315575247a03a5f
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
#importing sparksession
from pyspark.sql import SparkSession

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 4050 &')
# !curl -s http://localhost:4040/api/tunnels
# Out:
# --2023-02-01 06:22:11--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.237.133.81, 54.161.241.46, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.237.133.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  19.0MB/s    in 0.7s
#
# 2023-02-01 06:22:12 (19.0 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# {"tunnels":[],"uri":"/api/tunnels"}

# %%
#creating a sparksession object and providing appName 
spark=SparkSession.builder.appName("dataframe1").getOrCreate()

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 4050 &')
# !curl -s http://localhost:4040/api/tunnels
# Out:
# --2023-02-01 06:22:56--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.202.168.65, 54.237.133.81, 54.161.241.46, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.202.168.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  3.31MB/s    in 5.0s
#
# 2023-02-01 06:23:01 (2.64 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok
# ...

# %% [markdown]
# # Ways of Creating dataframe in pyspark

# %% [markdown]
# # Create Dataframe from Tuples

# %%
data = [(1, 'Dhoni', 'Male', 38, 10),
        (2, 'Virat' , 'Male', 30, 5),
        (3, 'Smriti', 'Female', 25, 9),
        (4, 'Sachin', 'Male', 45, 50),
        (5, 'Mitali', 'Female', 35, 7)
       ]

columns = ["ID", "Cricketer Name", "Gender", "Age", "Century"]

# %%
df = spark.createDataFrame(data, columns)

# %%
display(df)
# Out:
# DataFrame[ID: bigint, Cricketer Name: string, Gender: string, Age: bigint, Century: bigint]

# %%
df.show()
# Out:
# +---+--------------+------+---+-------+
# | ID|Cricketer Name|Gender|Age|Century|
# +---+--------------+------+---+-------+
# |  1|         Dhoni|  Male| 38|     10|
# |  2|         Virat|  Male| 30|      5|
# |  3|        Smriti|Female| 25|      9|
# |  4|        Sachin|  Male| 45|     50|
# |  5|        Mitali|Female| 35|      7|
# +---+--------------+------+---+-------+

# %% [markdown]
# # Create Dataframe from Dictionary

# %%
data = [{'Flower': 'Rose', 'price': 100, 'quantity': 10},
        {'Flower': 'Tulip', 'price': 500, 'quantity': 10},
        {'Flower': 'Sunflower', 'price': 400, 'quantity': 6},
        {'Flower': 'Jasmine', 'price': 100, 'quantity': 12}]

# %%
# creating a dataframe
df1 = spark.createDataFrame(data)

# %%
type(df1)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.show()
# Out:
# +---+--------------+------+---+-------+
# | ID|Cricketer Name|Gender|Age|Century|
# +---+--------------+------+---+-------+
# |  1|         Dhoni|  Male| 38|     10|
# |  2|         Virat|  Male| 30|      5|
# |  3|        Smriti|Female| 25|      9|
# |  4|        Sachin|  Male| 45|     50|
# |  5|        Mitali|Female| 35|      7|
# +---+--------------+------+---+-------+

# %%
#importing pandas library
import pandas as pd

# %%
pandasDF = pd.read_csv("airlines1.csv")

# %% [markdown]
# # Create Pandas Dataframe

# %%
pandasDF.shape
# Out:
# (50001, 110)

# %%
pandasDF
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0               0  1998        1      1           2          5  1998-01-02
# 1               1  2009        2      5          28          4  2009-05-28
# 2               2  2013        2      6          29          6  2013-06-29
# 3               3  2010        3      8          31          2  2010-08-31
# 4               4  2006        1      1          15          7  2006-01-15
# ...           ...   ...      ...    ...         ...        ...         ...
# 49996       49996  1999        4     10          12          2  1999-10-12
# 49997       49997  2010        4     11           1          1  2010-11-01
# 49998       49998  2006        2      4          30          7  2006-04-30
# 49999       49999  2009        3      7           8          3  2009-07-08
# 50000       50000  2006        2      5          17          3  2006-05-17
#
# ...

# %% [markdown]
# # Create spark Dataframe from Pandas Dataframe

# %% [markdown]
# # we need to cast all the columns in the pandas df to string type to overcome this datatype issue while converting pandas df to spark df

# %%
#sparkDF=spark.createDataFrame(pandasDF.astype(str))
sparkDF = spark.createDataFrame(pandasDF.astype(str))

# %%
sparkDF.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Quarter: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- DayofMonth: string (nullable = true)
#  |-- DayOfWeek: string (nullable = true)
#  |-- FlightDate: string (nullable = true)
#  |-- Reporting_Airline: string (nullable = true)
#  |-- DOT_ID_Reporting_Airline: string (nullable = true)
#  |-- IATA_CODE_Reporting_Airline: string (nullable = true)
#  |-- Tail_Number: string (nullable = true)
#  |-- Flight_Number_Reporting_Airline: string (nullable = true)
#  |-- OriginAirportID: string (nullable = true)
#  |-- OriginAirportSeqID: string (nullable = true)
#  |-- OriginCityMarketID: string (nullable = true)
#  |-- Origin: string (nullable = true)
#  |-- OriginCityName: string (nullable = true)
#  |-- OriginState: string (nullable = true)
#  |-- OriginStateFips: string (nullable = true)
#  |-- OriginStateName: string (nullable = true)
# ...

# %%
sparkDF.show(20)
# Out:
# +----------+----+-------+-----+----------+---------+----------+-----------------+------------------------+---------------------------+-----------+-------------------------------+---------------+------------------+------------------+------+--------------------+-----------+---------------+---------------+---------+-------------+----------------+----------------+----+--------------------+---------+-------------+--------------+-------+----------+-------+--------+---------------+--------+--------------------+----------+-------+---------+--------+------+----------+-------+--------+---------------+--------+------------------+----------+---------+----------------+--------+--------------+-----------------+-------+-------+--------+-------------+------------+------------+--------+-------------+-----------------+------------+-------------+---------------+------------------+--------------+--------------------+-----------+-----------+-----------+-------------+----------------+------------+--------
# ...

# %%
sparknewdf = sparkDF.select("Year", "Month", "DayofMonth" , "FlightDate","Tail_Number", "Flight_Number_Reporting_Airline" )

# %%
sparknewdf.show()
# Out:
# +----+-----+----------+----------+-----------+-------------------------------+
# |Year|Month|DayofMonth|FlightDate|Tail_Number|Flight_Number_Reporting_Airline|
# +----+-----+----------+----------+-----------+-------------------------------+
# |1998|    1|         2|1998-01-02|     N297US|                            675|
# |2009|    5|        28|2009-05-28|     N946AT|                            671|
# |2013|    6|        29|2013-06-29|     N665MQ|                           3297|
# |2010|    8|        31|2010-08-31|     N6705Y|                           1806|
# |2006|    1|        15|2006-01-15|     N504AU|                            465|
# |1995|   11|        29|1995-11-29|     N925DL|                           1198|
# |2006|    8|         7|2006-08-07|     N27724|                           1431|
# |2019|    6|        11|2019-06-11|     N927XJ|                           3459|
# |2008|    8|         3|2008-08-03|     N522LR|                           7233|
# ...

# %% [markdown]
# # Create Pandas Dataframe from Spark Dataframe

# %%
#pdf = sparknewdf.toPandas()
pdf = sparknewdf.toPandas()

# %%
from pyspark.sql.functions import date_format, format_string, date_add, to_timestamp, to_json

# %%
pdf
# Out:
#        Year Month DayofMonth  FlightDate Tail_Number  \
# 0      1998     1          2  1998-01-02      N297US
# 1      2009     5         28  2009-05-28      N946AT
# 2      2013     6         29  2013-06-29      N665MQ
# 3      2010     8         31  2010-08-31      N6705Y
# 4      2006     1         15  2006-01-15      N504AU
# ...     ...   ...        ...         ...         ...
# 49996  1999    10         12  1999-10-12        N311
# 49997  2010    11          1  2010-11-01      N940CA
# 49998  2006     4         30  2006-04-30      N509UA
# 49999  2009     7          8  2009-07-08      N804FR
# 50000  2006     5         17  2006-05-17      N388AA
#
#       Flight_Number_Reporting_Airline
# 0                                 675
# 1                                 671
# 2                                3297
# 3                                1806
# 4                                 465
# ...                               ...
# 49996                            1723
# ...

# %%
pdf1 = sparknewdf.toJSON()

# %%
display(pdf1)
# Out:
# MapPartitionsRDD[34] at toJavaRDD at NativeMethodAccessorImpl.java:0

# %% [markdown]
# Create Dataframe from csv file

# %%
#To create dataframe form External datasets
df = spark.read.option("header", "true").csv("airlines1.csv")

# %%
pdf2 = df.toPandas()

# %%
display(pdf2)
# Out:
#          _c0  Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0          0  1998       1     1          2         5  1998-01-02
# 1          1  2009       2     5         28         4  2009-05-28
# 2          2  2013       2     6         29         6  2013-06-29
# 3          3  2010       3     8         31         2  2010-08-31
# 4          4  2006       1     1         15         7  2006-01-15
# ...      ...   ...     ...   ...        ...       ...         ...
# 49996  49996  1999       4    10         12         2  1999-10-12
# 49997  49997  2010       4    11          1         1  2010-11-01
# 49998  49998  2006       2     4         30         7  2006-04-30
# 49999  49999  2009       3     7          8         3  2009-07-08
# 50000  50000  2006       2     5         17         3  2006-05-17
#
#       Reporting_Airline DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    NW                    19386                          NW
# ...
